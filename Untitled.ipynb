# %%
import pandas as pd

# %%
student=pd.read_csv('Student.csv')
course=pd.read_csv('Course.csv')
enrollment=pd.read_csv('Enrollment.csv')

# %%
student
# Out:
#      StudentID                  Name  Age      Gender             Class  \
# 0            1      Cyrill Dovermann   24        Male   Web Development
# 1            2            Essy Benzi   25      Female      Data Science
# 2            3           Tania Purle   18      Female   Web Development
# 3            4   Sheppard Raddenbury   23        Male      Data Science
# 4            5         Gaven Domnick   26        Male  Machine Learning
# ..         ...                   ...  ...         ...               ...
# 195        196          Kahlil Joney   20        Male      Data Science
# 196        197     Samuel Willingale   20        Male      Data Science
# 197        198             Cesar Bew   24        Male  Machine Learning
# 198        199  Jacquenetta Walewski   21  Polygender    Cyber Security
# 199        200     Frankie Dumbleton   23        Male    Cyber Security
#
#     Section                       Place DateOfBirth  CGPA
# ...

# %%
course.head(6)
# Out:
#    CourseID CourseName  Credits  Semester
# 0         1         Mr      3.7         1
# 1         2         Mr      3.6         4
# 2         3        Rev      5.0         5
# 3         4        Mrs      3.6         6
# 4         5        Mrs      4.5         1
# 5         6        Mrs      3.0         2

# %%
enrollment[enrollment['StudentID']==2]
# Out:
#      EnrollmentID  StudentID  CourseID EnrollmentDate FinalGrade       Status
# 160           161          2         6       9/4/2023          A  In Progress
